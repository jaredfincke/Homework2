# %%
### First, I installed the YELP API Library for Python.

# %%
pip install yelp
# Out:
# Requirement already satisfied: yelp in /Users/jfincke/opt/anaconda3/lib/python3.8/site-packages (1.0.2)
# Requirement already satisfied: six in /Users/jfincke/opt/anaconda3/lib/python3.8/site-packages (from yelp) (1.15.0)
# Requirement already satisfied: httplib2 in /Users/jfincke/opt/anaconda3/lib/python3.8/site-packages (from yelp) (0.18.1)
# Requirement already satisfied: oauth2 in /Users/jfincke/opt/anaconda3/lib/python3.8/site-packages (from yelp) (1.9.0.post1)
# Note: you may need to restart the kernel to use updated packages.

# %%
### I import the pandas program to perform the data analysis
### In an effort to hide my fusion API key, I will use the getpass function and enter my key in the input.

# %%
import pandas as pd
import requests
import getpass
api_key = getpass.getpass()
# Out:
# ········

# %%
### I then create a folder to hold the data and created the path using a condition statement.

# %%
path = "../Data"
os.mkdir(path)

# %%
### I then pull the all open coffee shops in Baltimore that have "Gender Neutral Restrooms" as their attribute

# %%
is_closed = "TRUE"
search_limit = 50
location = "Catonsville MD"
term = "Coffee"
url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'Businesses.is_closed': is_closed,
                'location': location.replace(' ', '+'),
                'limit': search_limit,
                'term' : term
            }
response = requests.get(url, headers = headers, params = url_params)
print(response)
print(type(response.text))
print(response.text[:1000])
# Out:
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "Puu6ZK3CVImi12h8_xwJag", "alias": "atwaters-catonsville-catonsville", "name": "Atwater's - Catonsville", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/xm0VsKFMF7q7dvZxfnWjXg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/atwaters-catonsville-catonsville?adjust_creative=nd2aTXKcQuP1kUkb9regqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd2aTXKcQuP1kUkb9regqw", "review_count": 189, "categories": [{"alias": "coffee", "title": "Coffee & Tea"}, {"alias": "bakeries", "title": "Bakeries"}, {"alias": "cafes", "title": "Cafes"}], "rating": 4.0, "coordinates": {"latitude": 39.27111, "longitude": -76.73442}, "transactions": ["delivery"], "price": "$", "location": {"address1": "815 Frederick Rd", "address2": "", "address3": "", "city": "Catonsville", "zip_code": "21228", "country": "US", "state": "MD", "display_address": ["815 Frederick Rd", "Catonsville, MD 21228"]}, "phone": "+14107474120", "display_phone": "(410) 747-4120",

# %%
### Using the Pandas, I put the json into a dataframe.

# %%
df = pd.DataFrame.from_dict(response.json()['businesses'])
print(len(df)) 
print(df.columns)
# Out:
# 50
# Index(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count',
#        'categories', 'rating', 'coordinates', 'transactions', 'price',
#        'location', 'phone', 'display_phone', 'distance'],
#       dtype='object')
#                        id                                    alias  \
# 0  Puu6ZK3CVImi12h8_xwJag         atwaters-catonsville-catonsville
# 1  slfuMJe3GeRPKtDUhFxiTg              caffe-di-roma-catonsville-2
# 2  XOR5zfNitIw3dREDg1Kt4A  gracefully-coffee-roasters-milford-mill
# 3  3RYRnXk4bsmmQCunF1vEDQ         coffee-on-main-street-elkridge-2
# 4  XqOMsfjXTpW0I7EfE3r9RQ                    starbucks-catonsville
#
#                          name  \
# 0     Atwater's - Catonsville
# 1               Caffe di Roma
# 2  Gracefully Coffee Roasters
# 3       Coffee on Main Street
# 4                   Starbucks
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/xm0VsK...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/Bb42Rc...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/yUp-w-...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/66bskE...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/jP_ii9...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/atwaters-catonsville-...           189
# 1  https://www.yelp.com/biz/caffe-di-roma-catonsv...            53
# 2  https://www.yelp.com/biz/gracefully-coffee-roa...            14
# 3  https://www.yelp.com/biz/coffee-on-main-street...            33
# 4  https://www.yelp.com/biz/starbucks-catonsville...            47
#
#                                           categories  rating  \
# 0  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.0
# 1  [{'alias': 'desserts', 'title': 'Desserts'}, {...     4.0
# 2  [{'alias': 'coffeeroasteries', 'title': 'Coffe...     5.0
# 3     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     4.5
# 4     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     3.5
#
#                                          coordinates transactions price  \
# 0     {'latitude': 39.27111, 'longitude': -76.73442}   [delivery]     $
# 1  {'latitude': 39.2733157, 'longitude': -76.754301}   [delivery]     $
# 2   {'latitude': 39.327598, 'longitude': -76.757382}           []   NaN
# 3  {'latitude': 39.2158069765315, 'longitude': -7...   [delivery]   NaN
# 4   {'latitude': 39.283384, 'longitude': -76.754702}   [delivery]    $$
#
#                                             location         phone  \
# 0  {'address1': '815 Frederick Rd', 'address2': '...  +14107474120
# 1  {'address1': '1719 Edmondson Ave', 'address2':...  +14107444747
# 2  {'address1': '2601 N Rolling Rd', 'address2': ...  +17862617477
# 3  {'address1': '5782 Main St', 'address2': '', '...  +14108622517
# 4  {'address1': '856 N Rolling Rd', 'address2': N...  +14108694641
#
#     display_phone     distance
# 0  (410) 747-4120  1201.170030
# 1  (410) 744-4747  1136.609645
# 2  (786) 261-7477  5499.845905
# 3  (410) 862-2517  7631.111550
# 4  (410) 869-4641  1056.448720

# %%
### I then pull the all open coffee shops in Dundalk, MD

# %%
is_closed = "TRUE"
search_limit = 50
location = "Dundalk MD"
term = "Coffee"

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'Businesses.is_closed': is_closed,
                'location': location.replace(' ', '+'),
                'limit': search_limit,
                'term' : term
            }
response = requests.get(url, headers = headers, params = url_params)
print(response)
print(type(response.text))
print(response.text[:1000])
# Out:
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "1OUdEM-V-KYLHRr-ADq_TA", "alias": "joannas-cafe-dundalk", "name": "Joanna's Cafe", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/DJl_nVJe9HGLJQl3y-Go4A/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/joannas-cafe-dundalk?adjust_creative=nd2aTXKcQuP1kUkb9regqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd2aTXKcQuP1kUkb9regqw", "review_count": 22, "categories": [{"alias": "breakfast_brunch", "title": "Breakfast & Brunch"}, {"alias": "salad", "title": "Salad"}, {"alias": "sandwiches", "title": "Sandwiches"}], "rating": 4.5, "coordinates": {"latitude": 39.275881, "longitude": -76.505672}, "transactions": ["pickup", "delivery"], "location": {"address1": "1420 Merritt Blvd", "address2": "Ste A", "address3": "", "city": "Dundalk", "zip_code": "21222", "country": "US", "state": "MD", "display_address": ["1420 Merritt Blvd", "Ste A", "Dundalk, MD 21222"]}, "phone": "+14435494797", "display_phone": "(443) 549-4797", "distanc

# %%
### Using the Pandas, I put the json into a dataframe and put the csv into the Data folder

# %%
ddf = pd.DataFrame.from_dict(response.json()['businesses'])
print(len(ddf)) 
print(ddf.columns) 
ddf.head() 

ddf.to_csv(r'../Data/raw_yelp_Dundalk.csv', index = False)
# Out:
# 50
# Index(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count',
#        'categories', 'rating', 'coordinates', 'transactions', 'location',
#        'phone', 'display_phone', 'distance', 'price'],
#       dtype='object')
#                        id                                   alias  \
# 0  1OUdEM-V-KYLHRr-ADq_TA                    joannas-cafe-dundalk
# 1  GcYE7r_yYf9x5gIf-xlVaQ       onedo-coffee-roasters-baltimore-2
# 2  AhimJlm3ipDF8GRC0Iha2w                          dunkin-dundalk
# 3  a5c8AmmG9y8kehmk92NP3w                     scoops-cafe-dundalk
# 4  _UTrlOdkgxlo15h-1zVo7g  aveley-farms-coffee-roasters-baltimore
#
#                            name  \
# 0                 Joanna's Cafe
# 1         OneDo Coffee Roasters
# 2                       Dunkin'
# 3                   Scoops Cafe
# 4  Aveley Farms Coffee Roasters
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/DJl_nV...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/KU1bVU...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/1eYuy1...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/ubH9Wz...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/fzZx_j...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/joannas-cafe-dundalk?...            22
# 1  https://www.yelp.com/biz/onedo-coffee-roasters...           103
# 2  https://www.yelp.com/biz/dunkin-dundalk?adjust...            14
# 3  https://www.yelp.com/biz/scoops-cafe-dundalk?a...             8
# 4  https://www.yelp.com/biz/aveley-farms-coffee-r...            53
#
#                                           categories  rating  \
# 0  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 1  [{'alias': 'coffeeroasteries', 'title': 'Coffe...     4.5
# 2  [{'alias': 'donuts', 'title': 'Donuts'}, {'ali...     3.5
# 3  [{'alias': 'korean', 'title': 'Korean'}, {'ali...     4.0
# 4  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     5.0
#
#                                          coordinates        transactions  \
# 0   {'latitude': 39.275881, 'longitude': -76.505672}  [pickup, delivery]
# 1  {'latitude': 39.2818782, 'longitude': -76.5781...          [delivery]
# 2        {'latitude': 39.2841, 'longitude': -76.506}          [delivery]
# 3       {'latitude': 39.257, 'longitude': -76.52228}          [delivery]
# 4   {'latitude': 39.283456, 'longitude': -76.598034}                  []
#
#                                             location         phone  \
# 0  {'address1': '1420 Merritt Blvd', 'address2': ...  +14435494797
# 1  {'address1': '913 S Lakewood Ave', 'address2':...  +14108140242
# 2  {'address1': '1099 Merritt Blvd', 'address2': ...  +14102882180
# 3  {'address1': '63 Shipping Pl', 'address2': '',...  +14102881988
# 4  {'address1': '1400 Aliceanna St', 'address2': ...  +14437085737
#
#     display_phone     distance price
# 0  (443) 549-4797   844.853717   NaN
# 1  (410) 814-0242  6822.491512    $$
# 2  (410) 288-2180  1560.739049     $
# 3  (410) 288-1988  2439.201830     $
# 4  (443) 708-5737  8537.496626   NaN

# %%
### I need to check if there are any missing values in both files.

# %%
print(df[df.isna().any(axis=1)])
# Out:
#                         id                                    alias  \
# 2   XOR5zfNitIw3dREDg1Kt4A  gracefully-coffee-roasters-milford-mill
# 3   3RYRnXk4bsmmQCunF1vEDQ         coffee-on-main-street-elkridge-2
# 9   ajnib-5m4eNZAcfnoCS59w    the-hub-asian-food-hall-catonsville-2
# 11  eGKz451ijLhB1m4Re4AA8A                jaxon-edwin-ellicott-city
# 19  x5S2zr8Cm6ehKIWyk2NLlg           vent-coffee-roasters-baltimore
# 31  A0ix-k9r9kmQL00TcEIkyQ                     dunkin-catonsville-2
# 40  2gI1rXlals8NgBPwYdT5Ow            unusual-company-ellicott-city
# 45  Re0fkcOCE6U5ccRn3C1LRw        park-ridge-creamery-ellicott-city
#
#                           name  \
# 2   Gracefully Coffee Roasters
# 3        Coffee on Main Street
# 9      The Hub Asian Food Hall
# 11                 Jaxon Edwin
# 19        Vent Coffee Roasters
# 31                     Dunkin'
# 40             Unusual Company
# 45         Park Ridge Creamery
#
#                                             image_url  is_closed  \
# 2   https://s3-media3.fl.yelpcdn.com/bphoto/yUp-w-...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/66bskE...      False
# 9   https://s3-media1.fl.yelpcdn.com/bphoto/rHGQHO...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/9KmEu0...      False
# 19  https://s3-media2.fl.yelpcdn.com/bphoto/Ja-F1P...      False
# 31  https://s3-media2.fl.yelpcdn.com/bphoto/MJsFYV...      False
# 40  https://s3-media2.fl.yelpcdn.com/bphoto/MHdq0x...      False
# 45  https://s3-media4.fl.yelpcdn.com/bphoto/flkC2e...      False
#
#                                                   url  review_count  \
# 2   https://www.yelp.com/biz/gracefully-coffee-roa...            14
# 3   https://www.yelp.com/biz/coffee-on-main-street...            33
# 9   https://www.yelp.com/biz/the-hub-asian-food-ha...            36
# 11  https://www.yelp.com/biz/jaxon-edwin-ellicott-...            16
# 19  https://www.yelp.com/biz/vent-coffee-roasters-...            34
# 31  https://www.yelp.com/biz/dunkin-catonsville-2?...             1
# 40  https://www.yelp.com/biz/unusual-company-ellic...             6
# 45  https://www.yelp.com/biz/park-ridge-creamery-e...            18
#
#                                            categories  rating  \
# 2   [{'alias': 'coffeeroasteries', 'title': 'Coffe...     5.0
# 3      [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     4.5
# 9   [{'alias': 'asianfusion', 'title': 'Asian Fusi...     4.5
# 11  [{'alias': 'barbers', 'title': 'Barbers'}, {'a...     5.0
# 19  [{'alias': 'coffeeroasteries', 'title': 'Coffe...     4.0
# 31  [{'alias': 'donuts', 'title': 'Donuts'}, {'ali...     2.0
# 40  [{'alias': 'comicbooks', 'title': 'Comic Books...     5.0
# 45  [{'alias': 'icecream', 'title': 'Ice Cream & F...     4.5
#
#                                           coordinates        transactions  \
# 2    {'latitude': 39.327598, 'longitude': -76.757382}                  []
# 3   {'latitude': 39.2158069765315, 'longitude': -7...          [delivery]
# 9     {'latitude': 39.28703, 'longitude': -76.761989}  [delivery, pickup]
# 11  {'latitude': 39.2673887112362, 'longitude': -7...                  []
# 19     {'latitude': 39.33628, 'longitude': -76.64412}          [delivery]
# 31  {'latitude': 39.2834858775404, 'longitude': -7...          [delivery]
# 40     {'latitude': 39.26722, 'longitude': -76.79686}                  []
# 45      {'latitude': 39.26686, 'longitude': -76.7993}          [delivery]
#
#    price                                           location         phone  \
# 2    NaN  {'address1': '2601 N Rolling Rd', 'address2': ...  +17862617477
# 3    NaN  {'address1': '5782 Main St', 'address2': '', '...  +14108622517
# 9    NaN  {'address1': '6510 Baltimore National Pike', '...  +16678025177
# 11   NaN  {'address1': '8191 Main Street', 'address2': '...  +14107507200
# 19   NaN  {'address1': '1700 W 41st St', 'address2': 'St...  +14436819410
# 31   NaN  {'address1': '6100 Old Frederick Rd', 'address...  +14433155951
# 40   NaN  {'address1': '8137 Main St', 'address2': None,...  +14107202828
# 45   NaN  {'address1': '3741 Hamilton St', 'address2': '...
#
#      display_phone      distance
# 2   (786) 261-7477   5499.845905
# 3   (410) 862-2517   7631.111550
# 9   (667) 802-5177   1799.583546
# 11  (410) 750-7200   4850.519744
# 19  (443) 681-9410  10609.978412
# 31  (443) 315-5951    601.666350
# 40  (410) 720-2828   4776.337642
# 45                   4985.311953

# %%
### I need the price, so I am going to get rid of everything with nan value.

# %%
cdf = df.dropna(axis = 'rows');

# %%
cddf = ddf.dropna(axis = 'rows');

# %%
### I'll export both clean data files.

# %%
cddf.to_csv(r'../Data/Clean_yelp_Dundalk.csv', index = False)
cdf.to_csv(r'../Data/Clean_yelp_Cville.csv', index = False)
